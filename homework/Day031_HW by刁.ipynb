# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
from bs4 import BeautifulSoup

#用知乎某篇文章做範例找headers
r = requests.get("https://zhuanlan.zhihu.com/p/107032494")
html = r.text
soup = BeautifulSoup( html , 'html.parser')
print(soup)
# Out:
# <html>
# <head><title>400 Bad Request</title></head>
# <body bgcolor="white">
# <center><h1>400 Bad Request</h1></center>
# <hr/><center>openresty</center>
# </body>
# </html>

# %%
headers={    
'authority': 'zhihu-web-analytics.zhihu.com',
'method': 'POST',
'path': '/api/v2/za/logs/batch',
'scheme': 'https',
'accept': '*/*',
'accept-encoding': 'gzip, deflate, br',
'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
'content-encoding': 'gzip',
'content-length': '557',
'content-type': 'application/x-protobuf',
'origin': 'https://zhuanlan.zhihu.com',
'referer': 'https://zhuanlan.zhihu.com/p/107032494',
'sec-fetch-mode': 'cors',
'sec-fetch-site': 'same-site',
'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
'x-za-batch-size': '3',
'x-za-clientid': '5511b5d4-d7ca-46da-af00-1856b10b6736',
'x-za-log-version': '2.6.25',
'x-za-platform': 'DesktopWeb',
'x-za-product': 'Zhihu'
}
r = requests.get("https://zhuanlan.zhihu.com/p/107032494", headers=headers )
html = r.text
soup = BeautifulSoup( html , 'html.parser')
print(soup)

#for d in soup.find_all('p')[1:]:
   # print(d.text)
# Out:
# <!DOCTYPE doctype html>
#
# ...

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
"""
全部加入就沒有問題

一般來講要加入accept-coding , user-agent , authority , method , path 即可

"""
# Out:
# '\n全部加入就沒有問題\n\n一般來講要加入accept-coding , user-agent , authority , method , path 即可\n\n'
