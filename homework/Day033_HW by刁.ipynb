# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/sex/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# C:\Users\User\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\User\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
res = requests.get('https://www.ptt.cc/bbs/sex/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# 看板 sex 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 sex
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 2
#
# [公告] 2020  叁月 西斯置底閒聊區
#
#
# Assisi
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Assisi 的文章
#
#
#  3/03
# M
#
#
#
# 2
#
#
# 				<tosay> 1-3-9 by 紅
#
#
#
# -
#
#
#  3/03
#
#
#
#
# 45
#
# Re: [閒聊] 高瘦的男生是不是
#
#
# nini21
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 nini21 的文章
#
#
#  3/03
#
#
#
#
#
#
#
# 				<YenFuOne> 1-3-9 by 紅
#
#
#
# -
#
#
#  3/03
#
#
#
#
#
#
#
# 				(本文已被刪除) [abc7360393]
#
#
#
# -
#
#
#  3/03
#
#
#
#
# 7
#
# Re: [討論] 女生願意被幹嘴巴的比例高嗎
#
#
# goldenrose
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 goldenrose 的文章
#
#
#  3/03
#
#
#
#
#
#
#
# 				(本文已被刪除) [pchunters]
#
#
#
# -
#
#
#  3/03
#
#
#
#
# 1
#
# [新聞] 高中女生讓他「凍沒條」色師廁所裝針孔
#
#
# zkow
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 zkow 的文章
#
#
#  3/03
#
#
#
#
# 9
#
# [閒聊] 有喜歡吞精的女生嗎
#
#
# pzhao
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 pzhao 的文章
#
#
#  3/03
#
#
#
#
#
#
#
# [公告] 西斯板規 Ver 6.2.9
#
#
# FallRed
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 FallRed 的文章
#
#
# 10/16
# !
#
#
#
#
#
# Fw: [公告] 請使用者多加注意我國保護兒少的法令
#
#
# FallRed
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 FallRed 的文章
#
#
#  7/29
# !
#
#
#
# 10
#
# [公告] 2019 冬季徵文 結果 暨 得獎名單
#
#
# Assisi
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Assisi 的文章
#
#
#  1/20
# M
#
#
#
#
#
# [公告] 2020 叁月 西斯置底閒聊區
#
#
# Assisi
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Assisi 的文章
#
#
#  3/03
#
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# C:\Users\User\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
