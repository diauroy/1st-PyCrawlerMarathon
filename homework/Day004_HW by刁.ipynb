# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
r=requests.get('https://api.github.com/events')
print(r) # 200 ok
print(r.text)
# Out:
# <Response [200]>
# [{"id":"10983166764","type":"PushEvent","actor":{"id":36153253,"login":"nickmoon0","display_login":"nickmoon0","gravatar_id":"","url":"https://api.github.com/users/nickmoon0","avatar_url":"https://avatars.githubusercontent.com/u/36153253?"},"repo":{"id":224981380,"name":"nickmoon0/IRC-Client-V2","url":"https://api.github.com/repos/nickmoon0/IRC-Client-V2"},"payload":{"push_id":4340282451,"size":1,"distinct_size":1,"ref":"refs/heads/Create-Channel","head":"381b7a2ae4aa53ba3080cdcdfbc83fdc206d3e57","before":"74d1393577bbc91b62bfec657e06d6fc55a9e91a","commits":[{"sha":"381b7a2ae4aa53ba3080cdcdfbc83fdc206d3e57","author":{"email":"nick@eliteyeet.com","name":"Nicholas Moon"},"message":"Removed bin/run:","distinct":true,"url":"https://api.github.com/repos/nickmoon0/IRC-Client-V2/commits/381b7a2ae4aa53ba3080cdcdfbc83fdc206d3e57"}]},"public":true,"created_at":"2019-12-01T13:10:30Z"},{"id":"10983166763","type":"IssueCommentEvent","actor":{"id":46527398,"login":"deemoartisan","display_login":"deemoartisan","gravatar_id":"","url":"https://api.github.com/users/deemoartisan","avatar_url":"https://avatars.githubusercontent.com/u/46527398?"},"repo":{"id":135238710,"name":"zzjzz9266a/91porn_php","url":"https://api.github.com/repos/zzjzz9266a/91porn_php"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/zzjzz9266a/91porn_php/issues/41","repository_url":"https://api.github.com/repos/zzjzz9266a/91porn_php","labels_url":"https://api.github.com/repos/zzjzz9266a/91porn_php/issues/41/labels{/name}","comments_url":"https://api.github.com/repos/zzjzz9266a/91porn_php/issues/41/comments","events_url":"https://api.github.com/repos/zzjzz9266a/91porn_php/issues/41/events","html_url":"https://github.com/zzjzz9266a/91porn_php/issues/41","id":482911297,"node_id":"MDU6SXNzdWU0ODI5MTEyOTc=","number":41,"title":"拉取了最新代码，下载出错请指导下","user":{"login":"usbcdrom","id":43695445,"node_id":"MDQ6VXNlcjQzNjk1NDQ1","avatar_url":"https://avatars3.githubusercontent.com/u/43695445?v=4","gravatar_id":"","url":"https://api.github.com/users/usbcdrom","html_url":"https://github.com/usbcdrom","followers_url":"https://api.github.com/users/usbcdrom/followers","following_url":"https://api.github.com/users/usbcdrom/following{/other_user}","gists_url":"https://api.github.com/users/usbcdrom/gists{/gist_id}","starred_url":"https://api.github.com/users/usbcdrom/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/usbcdrom/subscriptions","organizations_url":"https://api.github.com/users/usbcdrom/orgs","repos_url":"https://api.github.com/users/usbcdrom/repos","events_url":"https://api.github.com/users/usbcdrom/events{/privacy}","received_events_url":"https://api.github.com/users/usbcdrom/received_events","type":"User","site_admin":false},"labels":[],"state":"closed","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2019-08-20T14:53:12Z","updated_at":"2019-12-01T13:10:30Z","closed_at":"2019-08-29T08:21:11Z","author_association":"NONE","body":"没有做任何修改的情况下运行 php 91porn.php\r\n![QQ截图20190820225133](https://user-images.githubusercontent.com/43695445/63358129-20dac200-c39d-11e9-94aa-e6349bfe9c50.jpg)\r\n![QQ截图20190820225154](https://user-images.githubusercontent.com/43695445/63358132-21735880-c39d-11e9-8adf-43448ad1a924.jpg)\r\n\r\n"},"comment":{"url":"https://api.github.com/repos/zzjzz9266a/91porn_php/issues/comments/560106333","html_url":"https://github.com/zzjzz9266a/91porn_php/issues/41#issuecomment-560106333","issue_url":"https://api.github.com/repos/zzjzz9266a/91porn_php/issues/41","id":560106333,"node_id":"MDEyOklzc3VlQ29tbWVudDU2MDEwNjMzMw==","user":{"login":"deemoartisan","id":46527398,"node_id":"MDQ6VXNlcjQ2NTI3Mzk4","avatar_url":"https://avatars3.githubusercontent.com/u/46527398?v=4","gravatar_id":"","url":"https://api.github.com/users/deemoartisan","html_url":"https://github.com/deemoartisan","followers_url":"https://api.github.com/users/deemoartisan/followers","following_url":"https://api.github.com/u ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10983166764',
#   'type': 'PushEvent',
#   'actor': {'id': 36153253,
#    'login': 'nickmoon0',
#    'display_login': 'nickmoon0',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nickmoon0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36153253?'},
#   'repo': {'id': 224981380,
#    'name': 'nickmoon0/IRC-Client-V2',
#    'url': 'https://api.github.com/repos/nickmoon0/IRC-Client-V2'},
#   'payload': {'push_id': 4340282451,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Create-Channel',
#    'head': '381b7a2ae4aa53ba3080cdcdfbc83fdc206d3e57',
#    'before': '74d1393577bbc91b62bfec657e06d6fc55a9e91a',
#    'commits': [{'sha': '381b7a2ae4aa53ba3080cdcdfbc83fdc206d3e57',
#      'author': {'email': 'nick@eliteyeet.com', 'name': 'Nicholas Moon'},
#      'message': 'Removed bin/run:',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nickmoon0/IRC-Client-V2/commits/381b7a2ae4aa53ba3080cdcdfbc83fdc206d3e57'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166763',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 46527398,
#    'login': 'deemoartisan',
#    'display_login': 'deemoartisan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/deemoartisan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46527398?'},
#   'repo': {'id': 135238710,
#    'name': 'zzjzz9266a/91porn_php',
#    'url': 'https://api.github.com/repos/zzjzz9266a/91porn_php'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/zzjzz9266a/91porn_php/issues/41',
#     'repository_url': 'https://api.github.com/repos/zzjzz9266a/91porn_php',
#     'labels_url': 'https://api.github.com/repos/zzjzz9266a/91porn_php/issues/41/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/zzjzz9266a/91porn_php/issues/41/comments',
#     'events_url': 'https://api.github.com/repos/zzjzz9266a/91porn_php/issues/41/events',
#     'html_url': 'https://github.com/zzjzz9266a/91porn_php/issues/41',
#     'id': 482911297,
#     'node_id': 'MDU6SXNzdWU0ODI5MTEyOTc=',
#     'number': 41,
#     'title': '拉取了最新代码，下载出错请指导下',
#     'user': {'login': 'usbcdrom',
#      'id': 43695445,
#      'node_id': 'MDQ6VXNlcjQzNjk1NDQ1',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/43695445?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/usbcdrom',
#      'html_url': 'https://github.com/usbcdrom',
#      'followers_url': 'https://api.github.com/users/usbcdrom/followers',
#      'following_url': 'https://api.github.com/users/usbcdrom/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/usbcdrom/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/usbcdrom/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/usbcdrom/subscriptions',
#      'organizations_url': 'https://api.github.com/users/usbcdrom/orgs',
#      'repos_url': 'https://api.github.com/users/usbcdrom/repos',
#      'events_url': 'https://api.github.com/users/usbcdrom/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/usbcdrom/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-08-20T14:53:12Z',
#     'updated_at': '2019-12-01T13:10:30Z',
#     'closed_at': '2019-08-29T08:21:11Z',
#     'author_association': 'NONE',
#     'body': '没有做任何修改的情况下运行 php 91porn.php\r\n![QQ截图20190820225133](https://user-images.githubusercontent.com/43695445/63358129-20dac200-c39d-11e9-94aa-e6349bfe9c50.jpg)\r\n![QQ截图20190820225154](https://user-images.githubusercontent.com/43695445/63358132-21735880-c39d-11e9-8adf-43448ad1a924.jpg)\r\n\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/zzjzz9266a/91porn_php/issues/comments/560106333',
#     'html_url': 'https://github.com/zzjzz9266a/91porn_php/issues/41#issuecomment-560106333',
#     'issue_url': 'https://api.github.com/repos/zzjzz9266a/91porn_php/issues/41',
#     'id': 560106333,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MDEwNjMzMw==',
#     'user': {'login': 'deemoartisan',
#      'id': 46527398,
#      'node_id': 'MDQ6VXNlcjQ2NTI3Mzk4',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/46527398?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/deemoartisan',
#      'html_url': 'https://github.com/deemoartisan',
#      'followers_url': 'https://api.github.com/users/deemoartisan/followers',
#      'following_url': 'https://api.github.com/users/deemoartisan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/deemoartisan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/deemoartisan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/deemoartisan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/deemoartisan/orgs',
#      'repos_url': 'https://api.github.com/users/deemoartisan/repos',
#      'events_url': 'https://api.github.com/users/deemoartisan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/deemoartisan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-01T13:10:30Z',
#     'updated_at': '2019-12-01T13:10:30Z',
#     'author_association': 'NONE',
#     'body': '请问怎么解决的？'}},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166755',
#   'type': 'PushEvent',
#   'actor': {'id': 54942282,
#    'login': 'Pavana16',
#    'display_login': 'Pavana16',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Pavana16',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54942282?'},
#   'repo': {'id': 206572134,
#    'name': 'Pavana16/scripting-language',
#    'url': 'https://api.github.com/repos/Pavana16/scripting-language'},
#   'payload': {'push_id': 4340282445,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '37625ecd94ec91d0505f321dc05b09ca1ac70fa0',
#    'before': 'd78620071d7ba59327d3dad0ec52cf5e37e21109',
#    'commits': [{'sha': '37625ecd94ec91d0505f321dc05b09ca1ac70fa0',
#      'author': {'email': '54942282+Pavana16@users.noreply.github.com',
#       'name': 'Pavana16'},
#      'message': 'Rename titanic.py.txt to titanic.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Pavana16/scripting-language/commits/37625ecd94ec91d0505f321dc05b09ca1ac70fa0'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166756',
#   'type': 'DeleteEvent',
#   'actor': {'id': 46864422,
#    'login': 'ndomvi',
#    'display_login': 'ndomvi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ndomvi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46864422?'},
#   'repo': {'id': 220098630,
#    'name': 'ndomvi/FullStackOpen',
#    'url': 'https://api.github.com/repos/ndomvi/FullStackOpen'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/part2/data-for-countries/react-dom-16.12.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166754',
#   'type': 'PushEvent',
#   'actor': {'id': 44386561,
#    'login': 'seba3567',
#    'display_login': 'seba3567',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/seba3567',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44386561?'},
#   'repo': {'id': 213510495,
#    'name': 'Evert-Dev/vendor-evert-Q',
#    'url': 'https://api.github.com/repos/Evert-Dev/vendor-evert-Q'},
#   'payload': {'push_id': 4340282444,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Q',
#    'head': '0ebde37ce7b6f4c079777a8b229bd445204f9311',
#    'before': 'bd950a0005b083733933b548be4bd98d641e19f5',
#    'commits': [{'sha': '0ebde37ce7b6f4c079777a8b229bd445204f9311',
#      'author': {'email': 'sebastian26481@gmail.com', 'name': 'seba3567'},
#      'message': 'Revert "bluetooth from LA.UM.8.2.r1-04300-sdm660.0"\n\nThis reverts commit a34bc507f89014e32f8cdb585ccef1c39afbeb72.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Evert-Dev/vendor-evert-Q/commits/0ebde37ce7b6f4c079777a8b229bd445204f9311'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z',
#   'org': {'id': 52093344,
#    'login': 'Evert-Dev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Evert-Dev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52093344?'}},
#  {'id': '10983166745',
#   'type': 'PushEvent',
#   'actor': {'id': 36838913,
#    'login': 'adolphins',
#    'display_login': 'adolphins',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adolphins',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36838913?'},
#   'repo': {'id': 219939889,
#    'name': 'adolphins/glowing-winner',
#    'url': 'https://api.github.com/repos/adolphins/glowing-winner'},
#   'payload': {'push_id': 4340282440,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '31a2fa0477afae0325aa62a0ae88186fc0c03e08',
#    'before': '2f1b26754ec9212190576d970af5da88daafba34',
#    'commits': [{'sha': '31a2fa0477afae0325aa62a0ae88186fc0c03e08',
#      'author': {'email': '36838913+adolphins@users.noreply.github.com',
#       'name': 'A aaron'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adolphins/glowing-winner/commits/31a2fa0477afae0325aa62a0ae88186fc0c03e08'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166747',
#   'type': 'PushEvent',
#   'actor': {'id': 3737784,
#    'login': 'hajoch',
#    'display_login': 'hajoch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hajoch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3737784?'},
#   'repo': {'id': 157587660,
#    'name': 'hajoch/helpingno',
#    'url': 'https://api.github.com/repos/hajoch/helpingno'},
#   'payload': {'push_id': 4340282438,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '50157b4f701f2ec3c27f6687298ca0428845be5c',
#    'before': '1a58d10b8a4ce71c380e8c46cc7c0ec92654157c',
#    'commits': [{'sha': '50157b4f701f2ec3c27f6687298ca0428845be5c',
#      'author': {'email': 'helping.red@gmail.com',
#       'name': 'Gunnar Christensen'},
#      'message': 'Update from Forestry.io\nGunnar Christensen updated _posts/2019-07-01-nord-europas-høyeste-fjellovergang-1434-moh-sognefjellsvegen.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hajoch/helpingno/commits/50157b4f701f2ec3c27f6687298ca0428845be5c'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166751',
#   'type': 'PushEvent',
#   'actor': {'id': 33571437,
#    'login': 'Shikiiii',
#    'display_login': 'Shikiiii',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Shikiiii',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33571437?'},
#   'repo': {'id': 206498463,
#    'name': 'Shikiiii/Asmodeus',
#    'url': 'https://api.github.com/repos/Shikiiii/Asmodeus'},
#   'payload': {'push_id': 4340282441,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5f385413c8a72fc61726ed4d0c257864ee18f67e',
#    'before': '75b7dd6bb61e7a4430d20595ff906a9670de9984',
#    'commits': [{'sha': '5f385413c8a72fc61726ed4d0c257864ee18f67e',
#      'author': {'email': '33571437+Shikiiii@users.noreply.github.com',
#       'name': 'Shikii_'},
#      'message': 'Update fun.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Shikiiii/Asmodeus/commits/5f385413c8a72fc61726ed4d0c257864ee18f67e'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166746',
#   'type': 'PushEvent',
#   'actor': {'id': 8713940,
#    'login': 'damik21',
#    'display_login': 'damik21',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/damik21',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8713940?'},
#   'repo': {'id': 225160302,
#    'name': 'damik21/bars_test_task',
#    'url': 'https://api.github.com/repos/damik21/bars_test_task'},
#   'payload': {'push_id': 4340282437,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e71d615c7bfdd46e28c8649fde65baece019605a',
#    'before': '459baec26fd5804e295f39724eac28434530737a',
#    'commits': [{'sha': 'e71d615c7bfdd46e28c8649fde65baece019605a',
#      'author': {'email': 'damir.garifullin96@gmail.com', 'name': 'Damir'},
#      'message': 'Settings change',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/damik21/bars_test_task/commits/e71d615c7bfdd46e28c8649fde65baece019605a'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166744',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46632211,
#    'name': 'Lombiq/Orchard-Watcher',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Watcher'},
#   'payload': {'push_id': 4340282436,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/BTLR-63',
#    'head': 'fbca19354782064f6b8ecb1ab71329dad963839c',
#    'before': 'fbca19354782064f6b8ecb1ab71329dad963839c',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '10983166741',
#   'type': 'PushEvent',
#   'actor': {'id': 7227793,
#    'login': 'swabbass',
#    'display_login': 'swabbass',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swabbass',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7227793?'},
#   'repo': {'id': 55607504,
#    'name': 'wix/react-native-notifications',
#    'url': 'https://api.github.com/repos/wix/react-native-notifications'},
#   'payload': {'push_id': 4340282433,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/update-firebase',
#    'head': '71a1faf2911d925d7a23bd067bdb0299ddaf280b',
#    'before': '016e92714045d56607b55140731c228e2f9431a2',
#    'commits': [{'sha': '71a1faf2911d925d7a23bd067bdb0299ddaf280b',
#      'author': {'email': 'warda@wix.com', 'name': 'Ward Abbass'},
#      'message': 'Update gradle-wrapper.properties',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wix/react-native-notifications/commits/71a1faf2911d925d7a23bd067bdb0299ddaf280b'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z',
#   'org': {'id': 686511,
#    'login': 'wix',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wix',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/686511?'}},
#  {'id': '10983166743',
#   'type': 'PushEvent',
#   'actor': {'id': 16307144,
#    'login': '5john',
#    'display_login': '5john',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/5john',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16307144?'},
#   'repo': {'id': 211601139,
#    'name': '5john/5john',
#    'url': 'https://api.github.com/repos/5john/5john'},
#   'payload': {'push_id': 4340282422,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4bf18a33028617ab7615a9b7f30809cf5e8ee8ae',
#    'before': '706620edee891aaff68bc907cb075baa6561f547',
#    'commits': [{'sha': '4bf18a33028617ab7615a9b7f30809cf5e8ee8ae',
#      'author': {'email': '397633614@qq.com', 'name': '5john'},
#      'message': '2019/12/01 13:10:26    ymw3_c7o@linshiyouxiang.net',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/5john/5john/commits/4bf18a33028617ab7615a9b7f30809cf5e8ee8ae'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166742',
#   'type': 'PushEvent',
#   'actor': {'id': 44748420,
#    'login': 'ruswc',
#    'display_login': 'ruswc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ruswc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44748420?'},
#   'repo': {'id': 224662211,
#    'name': 'ruswc/js-band-hw-task-5',
#    'url': 'https://api.github.com/repos/ruswc/js-band-hw-task-5'},
#   'payload': {'push_id': 4340282435,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fdc7aa77b8d610d11259dc29f801565e4a579933',
#    'before': 'bc2c5ae3874314938f354b4128889d0b43b24ef6',
#    'commits': [{'sha': 'fdc7aa77b8d610d11259dc29f801565e4a579933',
#      'author': {'email': 'ruslanworkconsult@gmail.com', 'name': 'Ruslan'},
#      'message': 'travis: * (test) travis file completed',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ruswc/js-band-hw-task-5/commits/fdc7aa77b8d610d11259dc29f801565e4a579933'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166740',
#   'type': 'CreateEvent',
#   'actor': {'id': 58384221,
#    'login': 'longlong-123',
#    'display_login': 'longlong-123',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/longlong-123',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58384221?'},
#   'repo': {'id': 225161833,
#    'name': 'longlong-123/xintao1',
#    'url': 'https://api.github.com/repos/longlong-123/xintao1'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': '临时仓库',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166738',
#   'type': 'PushEvent',
#   'actor': {'id': 35521209,
#    'login': 'zsx0728',
#    'display_login': 'zsx0728',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zsx0728',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35521209?'},
#   'repo': {'id': 222623664,
#    'name': 'zsx0728/zsx0728.github.io',
#    'url': 'https://api.github.com/repos/zsx0728/zsx0728.github.io'},
#   'payload': {'push_id': 4340282429,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5855439c686171c9a5f1205316f06b0e6ca7ff09',
#    'before': '11e349b8d03da87c205b95c92c1bdeff2a0adf63',
#    'commits': [{'sha': '5855439c686171c9a5f1205316f06b0e6ca7ff09',
#      'author': {'email': '35521209+zsx0728@users.noreply.github.com',
#       'name': 'zsx0728'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zsx0728/zsx0728.github.io/commits/5855439c686171c9a5f1205316f06b0e6ca7ff09'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166733',
#   'type': 'PushEvent',
#   'actor': {'id': 19697989,
#    'login': 'Fenzland',
#    'display_login': 'Fenzland',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Fenzland',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19697989?'},
#   'repo': {'id': 218970041,
#    'name': 'FlyingGarden/Robberfly',
#    'url': 'https://api.github.com/repos/FlyingGarden/Robberfly'},
#   'payload': {'push_id': 4340282426,
#    'size': 2,
#    'distinct_size': 0,
#    'ref': 'refs/heads/src',
#    'head': '14fef78de9b68c114729a3845e60b080f609d983',
#    'before': 'fc89b77c71d28501231b8a18487a19d6641422f6',
#    'commits': [{'sha': '93ac4ee7fa51e061e1fe5eb5a58fa5516efcde2f',
#      'author': {'email': 'Fenzland@github.com', 'name': 'Fenzland'},
#      'message': 'runIsoEach() support worker limit',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/FlyingGarden/Robberfly/commits/93ac4ee7fa51e061e1fe5eb5a58fa5516efcde2f'},
#     {'sha': '14fef78de9b68c114729a3845e60b080f609d983',
#      'author': {'email': 'Fenzland@github.com', 'name': 'Fenzland'},
#      'message': 'add probe for the second parameter for test function',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/FlyingGarden/Robberfly/commits/14fef78de9b68c114729a3845e60b080f609d983'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z',
#   'org': {'id': 54537611,
#    'login': 'FlyingGarden',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/FlyingGarden',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54537611?'}},
#  {'id': '10983166736',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 1622923,
#    'login': 'shuujii',
#    'display_login': 'shuujii',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shuujii',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1622923?'},
#   'repo': {'id': 4073516,
#    'name': 'mruby/mruby',
#    'url': 'https://api.github.com/repos/mruby/mruby'},
#   'payload': {'action': 'opened',
#    'number': 4848,
#    'pull_request': {'url': 'https://api.github.com/repos/mruby/mruby/pulls/4848',
#     'id': 347327624,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ3MzI3NjI0',
#     'html_url': 'https://github.com/mruby/mruby/pull/4848',
#     'diff_url': 'https://github.com/mruby/mruby/pull/4848.diff',
#     'patch_url': 'https://github.com/mruby/mruby/pull/4848.patch',
#     'issue_url': 'https://api.github.com/repos/mruby/mruby/issues/4848',
#     'number': 4848,
#     'state': 'open',
#     'locked': False,
#     'title': 'Fix `MRB_FIXNUM_SHIFT` with `MRB_WORD_BOXING`, `MRB_INT32` and `MRB_64BIT`',
#     'user': {'login': 'shuujii',
#      'id': 1622923,
#      'node_id': 'MDQ6VXNlcjE2MjI5MjM=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/1622923?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/shuujii',
#      'html_url': 'https://github.com/shuujii',
#      'followers_url': 'https://api.github.com/users/shuujii/followers',
#      'following_url': 'https://api.github.com/users/shuujii/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/shuujii/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/shuujii/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/shuujii/subscriptions',
#      'organizations_url': 'https://api.github.com/users/shuujii/orgs',
#      'repos_url': 'https://api.github.com/users/shuujii/repos',
#      'events_url': 'https://api.github.com/users/shuujii/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/shuujii/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '### Example\n\n  ```ruby\n  # example.rb\n  max32 = 2**30 - 1 + 2**30\n  min32 = -max32-1\n  [max32, max32+1, min32, min32-1].each{|n| p [n, n.class]}\n  ```\n\n#### Before this patch:\n\n  ```\n  $ bin/mruby example.rb\n  [2147483647, Float]\n  [2147483648, Float]\n  [-2147483648, Float]\n  [-2147483649, Float]\n  ```\n\n#### After this patch:\n\n  ```\n  $ bin/mruby example.rb\n  [2147483647, Fixnum]\n  [2147483648, Float]\n  [-2147483648, Fixnum]\n  [-2147483649, Float]\n  ```',
#     'created_at': '2019-12-01T13:10:29Z',
#     'updated_at': '2019-12-01T13:10:29Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/mruby/mruby/pulls/4848/commits',
#     'review_comments_url': 'https://api.github.com/repos/mruby/mruby/pulls/4848/comments',
#     'review_comment_url': 'https://api.github.com/repos/mruby/mruby/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/mruby/mruby/issues/4848/comments',
#     'statuses_url': 'https://api.github.com/repos/mruby/mruby/statuses/a53f28275e14202ed2741920fcc32b9e2168d3d4',
#     'head': {'label': 'shuujii:fix-MRB_FIXNUM_SHIFT-with-MRB_WORD_BOXING-MRB_INT32-and-MRB_64BIT',
#      'ref': 'fix-MRB_FIXNUM_SHIFT-with-MRB_WORD_BOXING-MRB_INT32-and-MRB_64BIT',
#      'sha': 'a53f28275e14202ed2741920fcc32b9e2168d3d4',
#      'user': {'login': 'shuujii',
#       'id': 1622923,
#       'node_id': 'MDQ6VXNlcjE2MjI5MjM=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/1622923?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/shuujii',
#       'html_url': 'https://github.com/shuujii',
#       'followers_url': 'https://api.github.com/users/shuujii/followers',
#       'following_url': 'https://api.github.com/users/shuujii/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/shuujii/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/shuujii/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/shuujii/subscriptions',
#       'organizations_url': 'https://api.github.com/users/shuujii/orgs',
#       'repos_url': 'https://api.github.com/users/shuujii/repos',
#       'events_url': 'https://api.github.com/users/shuujii/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/shuujii/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 162793897,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjI3OTM4OTc=',
#       'name': 'mruby',
#       'full_name': 'shuujii/mruby',
#       'private': False,
#       'owner': {'login': 'shuujii',
#        'id': 1622923,
#        'node_id': 'MDQ6VXNlcjE2MjI5MjM=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/1622923?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/shuujii',
#        'html_url': 'https://github.com/shuujii',
#        'followers_url': 'https://api.github.com/users/shuujii/followers',
#        'following_url': 'https://api.github.com/users/shuujii/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/shuujii/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/shuujii/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/shuujii/subscriptions',
#        'organizations_url': 'https://api.github.com/users/shuujii/orgs',
#        'repos_url': 'https://api.github.com/users/shuujii/repos',
#        'events_url': 'https://api.github.com/users/shuujii/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/shuujii/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/shuujii/mruby',
#       'description': 'Lightweight Ruby',
#       'fork': True,
#       'url': 'https://api.github.com/repos/shuujii/mruby',
#       'forks_url': 'https://api.github.com/repos/shuujii/mruby/forks',
#       'keys_url': 'https://api.github.com/repos/shuujii/mruby/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/shuujii/mruby/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/shuujii/mruby/teams',
#       'hooks_url': 'https://api.github.com/repos/shuujii/mruby/hooks',
#       'issue_events_url': 'https://api.github.com/repos/shuujii/mruby/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/shuujii/mruby/events',
#       'assignees_url': 'https://api.github.com/repos/shuujii/mruby/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/shuujii/mruby/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/shuujii/mruby/tags',
#       'blobs_url': 'https://api.github.com/repos/shuujii/mruby/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/shuujii/mruby/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/shuujii/mruby/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/shuujii/mruby/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/shuujii/mruby/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/shuujii/mruby/languages',
#       'stargazers_url': 'https://api.github.com/repos/shuujii/mruby/stargazers',
#       'contributors_url': 'https://api.github.com/repos/shuujii/mruby/contributors',
#       'subscribers_url': 'https://api.github.com/repos/shuujii/mruby/subscribers',
#       'subscription_url': 'https://api.github.com/repos/shuujii/mruby/subscription',
#       'commits_url': 'https://api.github.com/repos/shuujii/mruby/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/shuujii/mruby/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/shuujii/mruby/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/shuujii/mruby/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/shuujii/mruby/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/shuujii/mruby/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/shuujii/mruby/merges',
#       'archive_url': 'https://api.github.com/repos/shuujii/mruby/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/shuujii/mruby/downloads',
#       'issues_url': 'https://api.github.com/repos/shuujii/mruby/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/shuujii/mruby/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/shuujii/mruby/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/shuujii/mruby/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/shuujii/mruby/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/shuujii/mruby/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/shuujii/mruby/deployments',
#       'created_at': '2018-12-22T08:14:36Z',
#       'updated_at': '2019-09-07T12:14:23Z',
#       'pushed_at': '2019-12-01T13:09:58Z',
#       'git_url': 'git://github.com/shuujii/mruby.git',
#       'ssh_url': 'git@github.com:shuujii/mruby.git',
#       'clone_url': 'https://github.com/shuujii/mruby.git',
#       'svn_url': 'https://github.com/shuujii/mruby',
#       'homepage': None,
#       'size': 13125,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'mruby:master',
#      'ref': 'master',
#      'sha': 'ef95a9fa93d4f9f8c0824e93486115dbefeee3a0',
#      'user': {'login': 'mruby',
#       'id': 1796512,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3OTY1MTI=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/1796512?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mruby',
#       'html_url': 'https://github.com/mruby',
#       'followers_url': 'https://api.github.com/users/mruby/followers',
#       'following_url': 'https://api.github.com/users/mruby/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mruby/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mruby/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mruby/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mruby/orgs',
#       'repos_url': 'https://api.github.com/users/mruby/repos',
#       'events_url': 'https://api.github.com/users/mruby/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mruby/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 4073516,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0MDczNTE2',
#       'name': 'mruby',
#       'full_name': 'mruby/mruby',
#       'private': False,
#       'owner': {'login': 'mruby',
#        'id': 1796512,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjE3OTY1MTI=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/1796512?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mruby',
#        'html_url': 'https://github.com/mruby',
#        'followers_url': 'https://api.github.com/users/mruby/followers',
#        'following_url': 'https://api.github.com/users/mruby/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mruby/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mruby/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mruby/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mruby/orgs',
#        'repos_url': 'https://api.github.com/users/mruby/repos',
#        'events_url': 'https://api.github.com/users/mruby/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mruby/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/mruby/mruby',
#       'description': 'Lightweight Ruby',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mruby/mruby',
#       'forks_url': 'https://api.github.com/repos/mruby/mruby/forks',
#       'keys_url': 'https://api.github.com/repos/mruby/mruby/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mruby/mruby/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mruby/mruby/teams',
#       'hooks_url': 'https://api.github.com/repos/mruby/mruby/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mruby/mruby/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mruby/mruby/events',
#       'assignees_url': 'https://api.github.com/repos/mruby/mruby/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mruby/mruby/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mruby/mruby/tags',
#       'blobs_url': 'https://api.github.com/repos/mruby/mruby/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mruby/mruby/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mruby/mruby/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mruby/mruby/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mruby/mruby/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mruby/mruby/languages',
#       'stargazers_url': 'https://api.github.com/repos/mruby/mruby/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mruby/mruby/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mruby/mruby/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mruby/mruby/subscription',
#       'commits_url': 'https://api.github.com/repos/mruby/mruby/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mruby/mruby/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mruby/mruby/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mruby/mruby/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mruby/mruby/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mruby/mruby/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mruby/mruby/merges',
#       'archive_url': 'https://api.github.com/repos/mruby/mruby/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mruby/mruby/downloads',
#       'issues_url': 'https://api.github.com/repos/mruby/mruby/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mruby/mruby/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mruby/mruby/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mruby/mruby/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mruby/mruby/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mruby/mruby/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mruby/mruby/deployments',
#       'created_at': '2012-04-19T09:11:15Z',
#       'updated_at': '2019-11-30T20:08:16Z',
#       'pushed_at': '2019-11-30T12:11:34Z',
#       'git_url': 'git://github.com/mruby/mruby.git',
#       'ssh_url': 'git@github.com:mruby/mruby.git',
#       'clone_url': 'https://github.com/mruby/mruby.git',
#       'svn_url': 'https://github.com/mruby/mruby',
#       'homepage': None,
#       'size': 13079,
#       'stargazers_count': 4496,
#       'watchers_count': 4496,
#       'language': 'C',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 682,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 178,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 682,
#       'open_issues': 178,
#       'watchers': 4496,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mruby/mruby/pulls/4848'},
#      'html': {'href': 'https://github.com/mruby/mruby/pull/4848'},
#      'issue': {'href': 'https://api.github.com/repos/mruby/mruby/issues/4848'},
#      'comments': {'href': 'https://api.github.com/repos/mruby/mruby/issues/4848/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mruby/mruby/pulls/4848/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mruby/mruby/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mruby/mruby/pulls/4848/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mruby/mruby/statuses/a53f28275e14202ed2741920fcc32b9e2168d3d4'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 1,
#     'additions': 30,
#     'deletions': 25,
#     'changed_files': 4}},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z',
#   'org': {'id': 1796512,
#    'login': 'mruby',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mruby',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1796512?'}},
#  {'id': '10983166729',
#   'type': 'PushEvent',
#   'actor': {'id': 46395105,
#    'login': 'Wangkaichn',
#    'display_login': 'Wangkaichn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Wangkaichn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46395105?'},
#   'repo': {'id': 225153489,
#    'name': 'Wangkaichn/My-Project',
#    'url': 'https://api.github.com/repos/Wangkaichn/My-Project'},
#   'payload': {'push_id': 4340282423,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '62f316cf80bdc4f1eae62e130b5ddf156dbe254d',
#    'before': '9565bb976e7a8e3d4bd8bd70d24b992aa99aeada',
#    'commits': [{'sha': '62f316cf80bdc4f1eae62e130b5ddf156dbe254d',
#      'author': {'email': '46395105+Wangkaichn@users.noreply.github.com',
#       'name': 'WangKai'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Wangkaichn/My-Project/commits/62f316cf80bdc4f1eae62e130b5ddf156dbe254d'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166730',
#   'type': 'PushEvent',
#   'actor': {'id': 1094029,
#    'login': 'raidensnake',
#    'display_login': 'raidensnake',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/raidensnake',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1094029?'},
#   'repo': {'id': 225147913,
#    'name': 'raidensnake/userland',
#    'url': 'https://api.github.com/repos/raidensnake/userland'},
#   'payload': {'push_id': 4340282428,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '37c45410ead68726bc1b36302a08045721ec430c',
#    'before': 'a040cb8927df01c11e0cea40e3bbdcb4c0dacdd3',
#    'commits': [{'sha': '37c45410ead68726bc1b36302a08045721ec430c',
#      'author': {'email': 'admin@raidensnakesden.net', 'name': 'raidensnake'},
#      'message': 'Update user-vcsm.c\n\nherew we go again...',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/raidensnake/userland/commits/37c45410ead68726bc1b36302a08045721ec430c'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z'},
#  {'id': '10983166725',
#   'type': 'PushEvent',
#   'actor': {'id': 55877031,
#    'login': 'G-Philippe',
#    'display_login': 'G-Philippe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/G-Philippe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55877031?'},
#   'repo': {'id': 223746198,
#    'name': 'APP-ISEP-G5E/sitePHPMVC',
#    'url': 'https://api.github.com/repos/APP-ISEP-G5E/sitePHPMVC'},
#   'payload': {'push_id': 4340282424,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '732e6be96d3a80f34c7d014c74758984f9a5f05b',
#    'before': '22d838f025f6ec7d3618a3bfb0df13ecd416faeb',
#    'commits': [{'sha': '732e6be96d3a80f34c7d014c74758984f9a5f05b',
#      'author': {'email': '55877031+G-Philippe@users.noreply.github.com',
#       'name': 'G-Philippe'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/APP-ISEP-G5E/sitePHPMVC/commits/732e6be96d3a80f34c7d014c74758984f9a5f05b'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z',
#   'org': {'id': 55878009,
#    'login': 'APP-ISEP-G5E',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/APP-ISEP-G5E',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55878009?'}},
#  {'id': '10983166727',
#   'type': 'DeleteEvent',
#   'actor': {'id': 803486,
#    'login': 'andrewvk',
#    'display_login': 'andrewvk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andrewvk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/803486?'},
#   'repo': {'id': 54007203,
#    'name': 'rsdn/CodeJam',
#    'url': 'https://api.github.com/repos/rsdn/CodeJam'},
#   'payload': {'ref': 'CJ-Cleanup',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z',
#   'org': {'id': 801693,
#    'login': 'rsdn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rsdn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/801693?'}},
#  {'id': '10983166726',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 33595554,
#    'login': 'lock[bot]',
#    'display_login': 'lock',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lock[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33595554?'},
#   'repo': {'id': 37191958,
#    'name': 'google-map-react/google-map-react',
#    'url': 'https://api.github.com/repos/google-map-react/google-map-react'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/google-map-react/google-map-react/issues/363',
#     'repository_url': 'https://api.github.com/repos/google-map-react/google-map-react',
#     'labels_url': 'https://api.github.com/repos/google-map-react/google-map-react/issues/363/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/google-map-react/google-map-react/issues/363/comments',
#     'events_url': 'https://api.github.com/repos/google-map-react/google-map-react/issues/363/events',
#     'html_url': 'https://github.com/google-map-react/google-map-react/issues/363',
#     'id': 221439960,
#     'node_id': 'MDU6SXNzdWUyMjE0Mzk5NjA=',
#     'number': 363,
#     'title': " error  'GoogleMapReact' is not defined",
#     'user': {'login': 'lordKnighton',
#      'id': 1773260,
#      'node_id': 'MDQ6VXNlcjE3NzMyNjA=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/1773260?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lordKnighton',
#      'html_url': 'https://github.com/lordKnighton',
#      'followers_url': 'https://api.github.com/users/lordKnighton/followers',
#      'following_url': 'https://api.github.com/users/lordKnighton/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lordKnighton/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lordKnighton/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lordKnighton/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lordKnighton/orgs',
#      'repos_url': 'https://api.github.com/users/lordKnighton/repos',
#      'events_url': 'https://api.github.com/users/lordKnighton/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lordKnighton/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2017-04-13T02:15:20Z',
#     'updated_at': '2019-12-01T13:10:29Z',
#     'closed_at': '2018-03-29T18:50:44Z',
#     'author_association': 'NONE',
#     'body': "```js \r\nimport React from 'react'\r\nimport ReactDOM from 'react-dom'\r\n\r\n\r\nconst AnyReactComponent = ({ text }) => (\r\n  <div style={{\r\n    position: 'relative', color: 'white', background: 'red',\r\n    height: 40, width: 60, top: -20, left: -30,\r\n  }}>\r\n    {text}\r\n  </div>\r\n);\r\n\r\nclass SimpleMap extends React.Component {\r\n  static defaultProps = {\r\n    center: {lat: 59.95, lng: 30.33},\r\n    zoom: 11\r\n  };\r\n\r\n  render() {\r\n    return (\r\n       <GoogleMapReact\r\n        defaultCenter={this.props.center}\r\n        defaultZoom={this.props.zoom}\r\n      >\r\n        <AnyReactComponent\r\n          lat={59.955413}\r\n          lng={30.337844}\r\n          text={'Kreyser Avrora'}\r\n        />\r\n      </GoogleMapReact>\r\n    );\r\n  }\r\n}\r\n\r\n\r\nReactDOM.render(\r\n  <div style={{width: '100%', height: '400px'}}>\r\n    <SimpleMap/>\r\n  </div>,\r\n  document.getElementById('main')\r\n);\r\n\r\n```"},
#    'comment': {'url': 'https://api.github.com/repos/google-map-react/google-map-react/issues/comments/560106332',
#     'html_url': 'https://github.com/google-map-react/google-map-react/issues/363#issuecomment-560106332',
#     'issue_url': 'https://api.github.com/repos/google-map-react/google-map-react/issues/363',
#     'id': 560106332,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MDEwNjMzMg==',
#     'user': {'login': 'lock[bot]',
#      'id': 33595554,
#      'node_id': 'MDM6Qm90MzM1OTU1NTQ=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/in/6672?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lock%5Bbot%5D',
#      'html_url': 'https://github.com/apps/lock',
#      'followers_url': 'https://api.github.com/users/lock%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/lock%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lock%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lock%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lock%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lock%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/lock%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/lock%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lock%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2019-12-01T13:10:29Z',
#     'updated_at': '2019-12-01T13:10:29Z',
#     'author_association': 'NONE',
#     'body': 'This thread has been automatically locked since there has not been any recent activity after it was closed. Please open a new issue for related bugs.'}},
#   'public': True,
#   'created_at': '2019-12-01T13:10:30Z',
#   'org': {'id': 37761132,
#    'login': 'google-map-react',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/google-map-react',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37761132?'}},
#  {'id': '10983166721',
#   'type': 'PushEvent',
#   'actor': {'id': 19697989,
#    'login': 'Fenzland',
#    'display_login': 'Fenzland',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Fenzland',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19697989?'},
#   'repo': {'id': 218970041,
#    'name': 'FlyingGarden/Robberfly',
#    'url': 'https://api.github.com/repos/FlyingGarden/Robberfly'},
#   'payload': {'push_id': 4340282415,
#    'size': 3,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '558b562590bc760356a879f8cc2c87b99f177e0c',
#    'before': '08fc41392c2ea6eb97351cc9d9266b61c21685b0',
#    'commits': [{'sha': '93ac4ee7fa51e061e1fe5eb5a58fa5516efcde2f',
#      'author': {'email': 'Fenzland@github.com', 'name': 'Fenzland'},
#      'message': 'runIsoEach() support worker limit',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/FlyingGarden/Robberfly/commits/93ac4ee7fa51e061e1fe5eb5a58fa5516efcde2f'},
#     {'sha': '14fef78de9b68c114729a3845e60b080f609d983',
#      'author': {'email': 'Fenzland@github.com', 'name': 'Fenzland'},
#      'message': 'add probe for the second parameter for test function',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/FlyingGarden/Robberfly/commits/14fef78de9b68c114729a3845e60b080f609d983'},
#     {'sha': '558b562590bc760356a879f8cc2c87b99f177e0c',
#      'author': {'email': 'Fenzland@github.com', 'name': 'Fenzland'},
#      'message': "Merge branch 'src'",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/FlyingGarden/Robberfly/commits/558b562590bc760356a879f8cc2c87b99f177e0c'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:29Z',
#   'org': {'id': 54537611,
#    'login': 'FlyingGarden',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/FlyingGarden',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54537611?'}},
#  {'id': '10983166717',
#   'type': 'PushEvent',
#   'actor': {'id': 48679375,
#    'login': 'joan41868',
#    'display_login': 'joan41868',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joan41868',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48679375?'},
#   'repo': {'id': 224930241,
#    'name': 'joan41868/hash-project',
#    'url': 'https://api.github.com/repos/joan41868/hash-project'},
#   'payload': {'push_id': 4340282414,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a1c385d75d2428ee13934b8758fe2d05c6426539',
#    'before': 'eb1ce4c632d7139e688ea6bcec0735bbb0c800a4',
#    'commits': [{'sha': 'a1c385d75d2428ee13934b8758fe2d05c6426539',
#      'author': {'email': 'yoansredkov@gmail.com', 'name': 'yoan'},
#      'message': 'minor fix',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/joan41868/hash-project/commits/a1c385d75d2428ee13934b8758fe2d05c6426539'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:29Z'},
#  {'id': '10983166712',
#   'type': 'PushEvent',
#   'actor': {'id': 49008515,
#    'login': 'Johanavh06',
#    'display_login': 'Johanavh06',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Johanavh06',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49008515?'},
#   'repo': {'id': 208297055,
#    'name': 'Andres20141684/eventrinet-frontend',
#    'url': 'https://api.github.com/repos/Andres20141684/eventrinet-frontend'},
#   'payload': {'push_id': 4340282410,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c07a425f7238393978de3cc122a0ab07121a7ef4',
#    'before': '9d72c468a11cbe8152d84bc3e4f000acaf2be556',
#    'commits': [{'sha': '1d446ac3ebd4565107bc3df902fefc5741450635',
#      'author': {'email': 'jin.manujos@hotmail.com', 'name': 'JinSSJ'},
#      'message': "Merge branch 'master' into JinSSJ4",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Andres20141684/eventrinet-frontend/commits/1d446ac3ebd4565107bc3df902fefc5741450635'},
#     {'sha': '54c4acbd7dabaedc76fb0006679e348989749280',
#      'author': {'email': 'jin.manujos@hotmail.com', 'name': 'JinSSJ'},
#      'message': 'Ya le quite el bton XDDD',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Andres20141684/eventrinet-frontend/commits/54c4acbd7dabaedc76fb0006679e348989749280'},
#     {'sha': 'c07a425f7238393978de3cc122a0ab07121a7ef4',
#      'author': {'email': '49008515+Johanavh06@users.noreply.github.com',
#       'name': 'Johanavh06'},
#      'message': 'Merge pull request #203 from Andres20141684/JinSSJ4\n\nJin ssj4',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Andres20141684/eventrinet-frontend/commits/c07a425f7238393978de3cc122a0ab07121a7ef4'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:29Z'},
#  {'id': '10983166713',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 6628437,
#    'login': '1138-4EB',
#    'display_login': '1138-4EB',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/1138-4EB',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6628437?'},
#   'repo': {'id': 212096477,
#    'name': 'numworks/setup-msys2',
#    'url': 'https://api.github.com/repos/numworks/setup-msys2'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/numworks/setup-msys2/issues/22',
#     'repository_url': 'https://api.github.com/repos/numworks/setup-msys2',
#     'labels_url': 'https://api.github.com/repos/numworks/setup-msys2/issues/22/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/numworks/setup-msys2/issues/22/comments',
#     'events_url': 'https://api.github.com/repos/numworks/setup-msys2/issues/22/events',
#     'html_url': 'https://github.com/numworks/setup-msys2/issues/22',
#     'id': 530727819,
#     'node_id': 'MDU6SXNzdWU1MzA3Mjc4MTk=',
#     'number': 22,
#     'title': 'Weird behavior chaining multiple commands using &&',
#     'user': {'login': 'jhasse',
#      'id': 80071,
#      'node_id': 'MDQ6VXNlcjgwMDcx',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/80071?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jhasse',
#      'html_url': 'https://github.com/jhasse',
#      'followers_url': 'https://api.github.com/users/jhasse/followers',
#      'following_url': 'https://api.github.com/users/jhasse/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jhasse/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jhasse/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jhasse/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jhasse/orgs',
#      'repos_url': 'https://api.github.com/users/jhasse/repos',
#      'events_url': 'https://api.github.com/users/jhasse/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jhasse/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-01T13:00:54Z',
#     'updated_at': '2019-12-01T13:10:29Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "I'm trying to port [an AppVeyor script](https://github.com/wxFormBuilder/wxFormBuilder/blob/cb8918b40b561f771f4161abc3b023d8be41d455/appveyor.yml) for wxFormBuilder [to GitHub Actions](https://github.com/wxFormBuilder/wxFormBuilder/pull/568). I've noticed that chaining a `cd` command with another one won't actually change the working directory. Only if I also add `ls && ` at the front: https://github.com/wxFormBuilder/wxFormBuilder/pull/568/commits/c05b987ef473522dbcb5025a98abbc2aeef9bef5\r\n\r\nI'm not really sure what's going on there, do you have an idea?"},
#    'comment': {'url': 'https://api.github.com/repos/numworks/setup-msys2/issues/comments/560106331',
#     'html_url': 'https://github.com/numworks/setup-msys2/issues/22#issuecomment-560106331',
#     'issue_url': 'https://api.github.com/repos/numworks/setup-msys2/issues/22',
#     'id': 560106331,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MDEwNjMzMQ==',
#     'user': {'login': '1138-4EB',
#      'id': 6628437,
#      'node_id': 'MDQ6VXNlcjY2Mjg0Mzc=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/6628437?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/1138-4EB',
#      'html_url': 'https://github.com/1138-4EB',
#      'followers_url': 'https://api.github.com/users/1138-4EB/followers',
#      'following_url': 'https://api.github.com/users/1138-4EB/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/1138-4EB/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/1138-4EB/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/1138-4EB/subscriptions',
#      'organizations_url': 'https://api.github.com/users/1138-4EB/orgs',
#      'repos_url': 'https://api.github.com/users/1138-4EB/repos',
#      'events_url': 'https://api.github.com/users/1138-4EB/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/1138-4EB/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-01T13:10:29Z',
#     'updated_at': '2019-12-01T13:10:29Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '`msys2do` does already include `bash -c`, you don\'t need to specify it:\r\n\r\nhttps://github.com/numworks/setup-msys2/blob/a59619f8cc2c4c08e51bb0d8f2dc41d8e2dae095/index.js#L37-L39\r\n\r\nSo, your commands are expanded to:\r\n\r\n```sh\r\n%~dp0\\\\msys64\\\\usr\\\\bin\\\\bash.exe -ilc "cd $OLDPWD && bash -c cd build/3.0/gmake && make config=release"\r\n\r\n%~dp0\\\\msys64\\\\usr\\\\bin\\\\bash.exe -ilc "cd $OLDPWD && bash -c ls && cd build/3.0/gmake && make config=release"\r\n```\r\n\r\nAs you see, `bash -c cd build/3.0/gmake` and `bash -c ls` are executed in children shells and have no effect on the commands before or after.'}},
#   'public': True,
#   'created_at': '2019-12-01T13:10:29Z',
#   'org': {'id': 22596700,
#    'login': 'numworks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/numworks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22596700?'}},
#  {'id': '10983166710',
#   'type': 'WatchEvent',
#   'actor': {'id': 13747187,
#    'login': 'forewing',
#    'display_login': 'forewing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/forewing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13747187?'},
#   'repo': {'id': 225120019,
#    'name': 'evil-huawei/evil-huawei',
#    'url': 'https://api.github.com/repos/evil-huawei/evil-huawei'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-01T13:10:29Z',
#   'org': {'id': 58351319,
#    'login': 'evil-huawei',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/evil-huawei',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58351319?'}},
#  {'id': '10983166705',
#   'type': 'PushEvent',
#   'actor': {'id': 39064217,
#    'login': 'alice-wercker',
#    'display_login': 'alice-wercker',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alice-wercker',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39064217?'},
#   'repo': {'id': 132497988,
#    'name': 'alice-wercker/hello-world-one',
#    'url': 'https://api.github.com/repos/alice-wercker/hello-world-one'},
#   'payload': {'push_id': 4340282407,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c7f3212a0b97d99ad346dae1512cc351aa3a3c4a',
#    'before': '66f8f03b5bacaf9c192a8fc74d336ff755c91710',
#    'commits': [{'sha': 'c7f3212a0b97d99ad346dae1512cc351aa3a3c4a',
#      'author': {'email': 'alice.wercker@gmail.com', 'name': 'Alice Wercker'},
#      'message': 'canary commit at 2019-12-01 13:10:25.341884929 +0000 UTC m=+6.310410552',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alice-wercker/hello-world-one/commits/c7f3212a0b97d99ad346dae1512cc351aa3a3c4a'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:29Z'},
#  {'id': '10983166702',
#   'type': 'CreateEvent',
#   'actor': {'id': 55906796,
#    'login': 'jg-konkuk',
#    'display_login': 'jg-konkuk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jg-konkuk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55906796?'},
#   'repo': {'id': 219666339,
#    'name': 'KwonSunJae/CppPA4',
#    'url': 'https://api.github.com/repos/KwonSunJae/CppPA4'},
#   'payload': {'ref': 'ajg',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'c++ 3조 팀플',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T13:10:29Z'},
#  {'id': '10983166701',
#   'type': 'PushEvent',
#   'actor': {'id': 54777217,
#    'login': 'DiyaAc',
#    'display_login': 'DiyaAc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DiyaAc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54777217?'},
#   'repo': {'id': 208086311,
#    'name': 'marceldubach/HeatTransfer',
#    'url': 'https://api.github.com/repos/marceldubach/HeatTransfer'},
#   'payload': {'push_id': 4340282401,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e6adac6a3de50dc61b211bca34726c3b73a2330b',
#    'before': '04f98f4ce255ff65b651f1490ce13b1a2ec1d469',
#    'commits': [{'sha': 'e6adac6a3de50dc61b211bca34726c3b73a2330b',
#      'author': {'email': 'diya.achi@epfl.ch', 'name': 'DiyaAc'},
#      'message': 'Boiling table',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/marceldubach/HeatTransfer/commits/e6adac6a3de50dc61b211bca34726c3b73a2330b'}]},
#   'public': True,
#   'created_at': '2019-12-01T13:10:29Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
para= {'key1': 'value1', 'key2': 'value2'}
r = requests.get("https://cat-fact.herokuapp.com/facts", params=para)
json.loads(r.text)
# Out:
# {'all': [{'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
#     'name': {'first': 'David', 'last': 'Gippner'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
r=requests.get("https://cat-fact.herokuapp.com/facts")
json.loads(r.text)
# Out:
# {'all': [{'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008b80aac31001185ed0d',
#    'text': 'Adult cats only meow to communicate with humans.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009650aac31001185ed13',
#    'text': 'In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58f9b96132ffea00208fe9b7',
#    'text': 'rerewr',
#    'type': 'cat',
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '587288f6e6f85e64ae1c7ef7',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
#    'text': "Cats don't go through menopause, so they can continue to breed into their senior years.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c470572a99c3f00140fe4bd',
#    'text': 'Cats like being brushed by their owners, because it reminds them of their mother.',
#    'type': 'cat',
#    'user': {'_id': '5c470492a99c3f00140fe4bc',
#     'name': {'first': 'David', 'last': 'Gippner'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
# r.text 和 json.loads(r.text)差異

#一個是字串類別  一個是字典類別
print(type(r.text),type(json.loads(r.text)))
# Out:
# <class 'str'> <class 'dict'>
